# %%
import gdsfactory as gf

# %%
mzi = gf.components.mzi2x2_2x2_phase_shifter(delta_length=10, length_y=2, length_x=10, bend='bend_euler', straight='straight', straight_x_top='straight_heater_metal', splitter='mmi2x2', combiner='mmi2x2', with_splitter=True, port_e1_splitter='o3', port_e0_splitter='o4', port_e1_combiner='o3', port_e0_combiner='o4', port1='o1', port2='o2', nbends=2, cross_section='strip', mirror_bot=False, add_optical_ports_arms=False, min_length=0.01, auto_rename_ports=True).copy()

mzi.pprint_ports()

mzi.plot()

mzi.plot_netlist()
# Out:
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/1002109295.py:1: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   mzi = gf.components.mzi2x2_2x2_phase_shifter(delta_length=10, length_y=2, length_x=10, bend='bend_euler', straight='straight', straight_x_top='straight_heater_metal', splitter='mmi2x2', combiner='mmi2x2', with_splitter=True, port_e1_splitter='o3', port_e0_splitter='o4', port_e1_combiner='o3', port_e0_combiner='o4', port1='o1', port2='o2', nbends=2, cross_section='strip', mirror_bot=False, add_optical_ports_arms=False, min_length=0.01, auto_rename_ports=True).copy()
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center          ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ o1   │ 0.5   │ 180.0       │ WG (1/0)    │ (-10.0, -0.625) │ optical    │
# │ o2   │ 0.5   │ 180.0       │ WG (1/0)    │ (-10.0, 0.625)  │ optical    │
# │ o4   │ 0.5   │ 0.0         │ WG (1/0)    │ (91.0, -0.625)  │ optical    │
# │ o3   │ 0.5   │ 0.0         │ WG (1/0)    │ (91.0, 0.625)   │ optical    │
# │ e1   │ 11.0  │ 180.0       │ MTOP (49/0) │ (19.6, 22.625)  │ electrical │
# │ e3   │ 11.0  │ 90.0        │ MTOP (49/0) │ (25.1, 28.125)  │ electrical │
# │ e6   │ 11.0  │ 0.0         │ MTOP (49/0) │ (30.6, 22.625)  │ electrical │
# │ e8   │ 11.0  │ 270.0       │ MTOP (49/0) │ (25.1, 17.125)  │ electrical │
# │ e2   │ 11.0  │ 180.0       │ MTOP (49/0) │ (50.4, 22.625)  │ electrical │
# │ e4   │ 11.0  │ 90.0        │ MTOP (49/0) │ (55.9, 28.125)  │ electrical │
# │ e5   │ 11.0  │ 0.0         │ MTOP (49/0) │ (61.4, 22.625)  │ electrical │
# │ e7   │ 11.0  │ 270.0       │ MTOP (49/0) │ (55.9, 17.125)  │ electrical │
# └──────┴───────┴─────────────┴─────────────┴─────────────────┴────────────┘

# %%
bend_s = gf.components.bend_euler_s(radius=20,p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

bend_s.plot()

bend_s.plot_netlist()
# Out:
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/1701308711.py:1: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   bend_s = gf.components.bend_euler_s(radius=20,p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

# %%
bend_s_heater = gf.components.bend_euler_s(radius=20,p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

heater_cell = gf.components.via_stack_heater_mtop_mini(size=(10, 10), layers=('HEATER', 'M2', 'MTOP'), correct_size=True, slot_horizontal=False, slot_vertical=False, port_orientations=(180, 90, 0, -90)).copy()

heater = bend_s_heater << heater_cell
heater.movex(20)
heater.movey(20)

bend_s_heater.add_port(name="e1", port=heater.ports["e1"]) # TO-CHECK ORENTATION!!!

bend_s_heater.pprint_ports()

bend_s_heater.plot()

bend_s_heater.plot_netlist()
# Out:
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/3014352610.py:1: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   bend_s_heater = gf.components.bend_euler_s(radius=20,p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/3014352610.py:3: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   heater_cell = gf.components.via_stack_heater_mtop_mini(size=(10, 10), layers=('HEATER', 'M2', 'MTOP'), correct_size=True, slot_horizontal=False, slot_vertical=False, port_orientations=(180, 90, 0, -90)).copy()
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center       ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ o1   │ 0.5   │ 180.0       │ WG (1/0)    │ (0.0, 0.0)   │ optical    │
# │ o2   │ 0.5   │ 0.0         │ WG (1/0)    │ (40.0, 40.0) │ optical    │
# │ e1   │ 10.0  │ 180.0       │ MTOP (49/0) │ (15.0, 20.0) │ electrical │
# └──────┴───────┴─────────────┴─────────────┴──────────────┴────────────┘

# %%
bend_s_mirror = gf.components.bend_euler_s(radius=20, p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

bend_s_mirror.plot()

bend_s_mirror.plot_netlist()
# Out:
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/2562017023.py:1: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   bend_s_mirror = gf.components.bend_euler_s(radius=20, p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

# %%
bend_s_mirror_heater = gf.components.bend_euler_s(radius=20, p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()

# bend_s_mirror_heater.mirror_y()

heater_cell = gf.components.via_stack_heater_mtop_mini(size=(10, 10), layers=('HEATER', 'M2', 'MTOP'), correct_size=True, slot_horizontal=False, slot_vertical=False, port_orientations=(180, 90, 0, -90)).copy()

heater = bend_s_mirror_heater << heater_cell
heater.movex(20)
heater.movey(20)

bend_s_mirror_heater.add_port(name="e1", port=heater.ports["e1"]) # TO-CHECK ORENTATION!!!

bend_s_mirror_heater.pprint_ports()

bend_s_mirror_heater.plot()

bend_s_mirror_heater.plot_netlist()
# Out:
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/822750241.py:1: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   bend_s_mirror_heater = gf.components.bend_euler_s(radius=20, p=0.5, with_arc_floorplan=True, cross_section='strip', allow_min_radius_violation=False, port1='o1', port2='o2').copy()
# /var/folders/fr/t8w_2pkd0_z3xg500tnxww5c0000gn/T/ipykernel_75765/822750241.py:5: UserWarning: copy() is deprecated and will be removed in gdsfactory9. Please use dup() instead.
#   heater_cell = gf.components.via_stack_heater_mtop_mini(size=(10, 10), layers=('HEATER', 'M2', 'MTOP'), correct_size=True, slot_horizontal=False, slot_vertical=False, port_orientations=(180, 90, 0, -90)).copy()
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center       ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ o1   │ 0.5   │ 180.0       │ WG (1/0)    │ (0.0, 0.0)   │ optical    │
# │ o2   │ 0.5   │ 0.0         │ WG (1/0)    │ (40.0, 40.0) │ optical    │
# │ e1   │ 10.0  │ 180.0       │ MTOP (49/0) │ (15.0, 20.0) │ electrical │
# └──────┴───────┴─────────────┴─────────────┴──────────────┴────────────┘

# %%
@gf.cell
def mzi_cell_gf():
    c = gf.Component()
    mziRef = c.add_ref(mzi, name="mzi")
    s1 = c.add_ref(bend_s, name="bend1")
    s2 = c.add_ref(bend_s_mirror, name="bend2")
    s3 = c.add_ref(bend_s_heater, name="bend3")
    s4 = c.add_ref(bend_s_mirror_heater, name="bend4")
    s1.connect("o2", mziRef.ports["o1"]) # connecting port-"o2"-of-bends1 to port-"o1"-of-mzi1 
    s2.connect("o2", mziRef.ports["o2"], mirror=True) # connecting port-"o2"-of-bends2 to port-"o2"-of-mzi1 
    s3.connect("o1", mziRef.ports["o3"]) # connecting port-"o1"-of-bends3 to port-"o3"-of-mzi1 
    s4.connect("o1", mziRef.ports["o4"], mirror=True) # connecting port-"o1"-of-bends4 to port-"o4"-of-mzi1 
    c.add_port(name="i1", port=s1.ports["o1"]) # defining port-"o1"-of-bends1 as port-"p1"-of-mzi_cell
    c.add_port(name="i2", port=s2.ports["o1"]) # defining port-"o1"-of-bends2 as port-"p2"-of-mzi_cell
    c.add_port(name="o2", port=s3.ports["o2"]) # defining port-"o2"-of-bends3 as port-"p3"-of-mzi_cell
    c.add_port(name="o1", port=s4.ports["o2"]) # defining port-"o2"-of-bends4 as port-"p4"-of-mzi_cell
    # === electrical ports ===
    c.add_port(name="ei1", port=mziRef.ports["e3"])
    c.add_port(name="eo1", port=s3.ports["e1"])
    c.add_port(name="eo2", port=s4.ports["e1"])
    return c

mzi_cell_Gf = mzi_cell_gf()
mzi_cell_Gf.plot()

mzi_cell_Gf.pprint_ports()

# mzi_cell_Gf.draw_ports()

mzi_cell_Gf.plot_netlist()
# Out:
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center           ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ i1   │ 0.5   │ 180.0       │ WG (1/0)    │ (-50.0, -40.625) │ optical    │
# │ i2   │ 0.5   │ 180.0       │ WG (1/0)    │ (-50.0, 40.625)  │ optical    │
# │ o2   │ 0.5   │ 0.0         │ WG (1/0)    │ (131.0, 40.625)  │ optical    │
# │ o1   │ 0.5   │ 0.0         │ WG (1/0)    │ (131.0, -40.625) │ optical    │
# │ ei1  │ 11.0  │ 90.0        │ MTOP (49/0) │ (25.1, 28.125)   │ electrical │
# │ eo1  │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, 20.625)  │ electrical │
# │ eo2  │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, -20.625) │ electrical │
# └──────┴───────┴─────────────┴─────────────┴──────────────────┴────────────┘

# %%
mzi_cell = gf.Component() # defining new "blank" component as mzi_cell

mzi1 = mzi_cell << mzi # defining new mzi inside mzi_cell as "mzi1"

bends1 = mzi_cell << bend_s # defining new s-bend
bends2 = mzi_cell << bend_s_mirror # defining new mirrored s-bend
bends3 = mzi_cell << bend_s_heater # defining new s-bend
bends4 = mzi_cell << bend_s_mirror_heater # defining new mirrored s-bend

bends1.connect("o2", mzi1.ports["o1"]) # connecting port-"o2"-of-bends1 to port-"o1"-of-mzi1 
bends2.connect("o2", mzi1.ports["o2"], mirror=True) # connecting port-"o2"-of-bends2 to port-"o2"-of-mzi1 
bends3.connect("o1", mzi1.ports["o3"]) # connecting port-"o1"-of-bends3 to port-"o3"-of-mzi1 
bends4.connect("o1", mzi1.ports["o4"], mirror=True) # connecting port-"o1"-of-bends4 to port-"o4"-of-mzi1 

mzi_cell.add_port(name="i1", port=bends1.ports["o1"]) # defining port-"o1"-of-bends1 as port-"p1"-of-mzi_cell
mzi_cell.add_port(name="i2", port=bends2.ports["o1"]) # defining port-"o1"-of-bends2 as port-"p2"-of-mzi_cell
mzi_cell.add_port(name="o2", port=bends3.ports["o2"]) # defining port-"o2"-of-bends3 as port-"p3"-of-mzi_cell
mzi_cell.add_port(name="o1", port=bends4.ports["o2"]) # defining port-"o2"-of-bends4 as port-"p4"-of-mzi_cell

# === electrical ports ===
mzi_cell.add_port(name="ei1", port=mzi1.ports["e3"])
mzi_cell.add_port(name="eo1", port=bends3.ports["e1"])
mzi_cell.add_port(name="eo2", port=bends4.ports["e1"])

mzi_cell.plot()

mzi_cell.plot_netlist()

mzi_cell.pprint_ports()
# Out:
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center           ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ i1   │ 0.5   │ 180.0       │ WG (1/0)    │ (-50.0, -40.625) │ optical    │
# │ i2   │ 0.5   │ 180.0       │ WG (1/0)    │ (-50.0, 40.625)  │ optical    │
# │ o2   │ 0.5   │ 0.0         │ WG (1/0)    │ (131.0, 40.625)  │ optical    │
# │ o1   │ 0.5   │ 0.0         │ WG (1/0)    │ (131.0, -40.625) │ optical    │
# │ ei1  │ 11.0  │ 90.0        │ MTOP (49/0) │ (25.1, 28.125)   │ electrical │
# │ eo1  │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, 20.625)  │ electrical │
# │ eo2  │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, -20.625) │ electrical │
# └──────┴───────┴─────────────┴─────────────┴──────────────────┴────────────┘

# %%
import gplugins as sim
import gplugins.tidy3d as gt

import ubcpdk.components as pdk
from ubcpdk.config import PATH

# %%
# sp = gt.write_sparameters(mzi_cell, filepath=PATH.sparameters / "mzi_cell.npz")

# %%
nm = 1e-3
coupling = 0.5
kappa = coupling**0.5
tau = (1 - coupling) ** 0.5
coupler_dict = {
    ("o1", "o4"): tau,
    ("o4", "o1"): tau,
    ("o1", "o3"): 1j * kappa,
    ("o3", "o1"): 1j * kappa,
    ("o2", "o4"): 1j * kappa,
    ("o4", "o2"): 1j * kappa,
    ("o2", "o3"): tau,
    ("o3", "o2"): tau,
}
coupler_dict
# Out:
# {('o1', 'o4'): 0.7071067811865476,
#  ('o4', 'o1'): 0.7071067811865476,
#  ('o1', 'o3'): 0.7071067811865476j,
#  ('o3', 'o1'): 0.7071067811865476j,
#  ('o2', 'o4'): 0.7071067811865476j,
#  ('o4', 'o2'): 0.7071067811865476j,
#  ('o2', 'o3'): 0.7071067811865476,
#  ('o3', 'o2'): 0.7071067811865476}

# %%
coupler_dict = sax.reciprocal(
    {
        ("o1", "o4"): tau,
        ("o1", "o3"): 1j * kappa,
        ("o2", "o4"): 1j * kappa,
        ("o2", "o3"): tau,
    }
)

coupler_dict
# Out:
# {('o1', 'o4'): 0.7071067811865476,
#  ('o1', 'o3'): 0.7071067811865476j,
#  ('o2', 'o4'): 0.7071067811865476j,
#  ('o2', 'o3'): 0.7071067811865476,
#  ('o4', 'o1'): 0.7071067811865476,
#  ('o3', 'o1'): 0.7071067811865476j,
#  ('o4', 'o2'): 0.7071067811865476j,
#  ('o3', 'o2'): 0.7071067811865476}

# %%
mziMatrix = gf.Component()

# ========================================
#       defining MZIs
# ========================================
mzi_cell1 = mziMatrix << mzi_cell_Gf
mzi_cell2 = mziMatrix << mzi_cell_Gf
mzi_cell3 = mziMatrix << mzi_cell_Gf
mzi_cell4 = mziMatrix << mzi_cell_Gf
mzi_cell5 = mziMatrix << mzi_cell_Gf
mzi_cell6 = mziMatrix << mzi_cell_Gf

# # ========================================
# #      MZIs labeling
# # ========================================
# mziMatrix.add_label(text="MZI111", position=mzi_cell1.dcenter)
# mziMatrix.add_label(text="MZI222", position=mzi_cell2.dcenter)
# mziMatrix.add_label(text="MZI333", position=mzi_cell3.dcenter)
# mziMatrix.add_label(text="MZI444", position=mzi_cell4.dcenter)
# mziMatrix.add_label(text="MZI555", position=mzi_cell5.dcenter)
# mziMatrix.add_label(text="MZI666", position=mzi_cell6.dcenter)

# ========================================
#       connect and routing
# ========================================
mzi_cell1.connect("o2", mzi_cell2.ports["i1"])
mzi_cell4.connect("i2", mzi_cell2.ports["o1"])
route14 = gf.routing.route_single(
    mziMatrix,
    port1=mzi_cell1.ports["o1"],
    port2=mzi_cell4.ports["i1"],
    cross_section=gf.cross_section.strip,
)
mzi_cell3.connect("i1", mzi_cell2.ports["o2"])
mzi_cell5.connect("i1", mzi_cell4.ports["o2"])
mzi_cell5.connect("i2", mzi_cell3.ports["o1"])
mzi_cell6.connect("i2", mzi_cell5.ports["o1"])
route46 = gf.routing.route_single(
    mziMatrix,
    port1=mzi_cell4.ports["o1"],
    port2=mzi_cell6.ports["i1"],
    cross_section=gf.cross_section.strip,
)

# ========================================
#       optical ports
# ========================================
mziMatrix.add_port(name="in1", port=mzi_cell1.ports["i1"])
mziMatrix.add_port(name="in2", port=mzi_cell1.ports["i2"])
mziMatrix.add_port(name="in3", port=mzi_cell2.ports["i2"])
mziMatrix.add_port(name="in4", port=mzi_cell3.ports["i2"])
mziMatrix.add_port(name="out4", port=mzi_cell3.ports["o2"])
mziMatrix.add_port(name="out3", port=mzi_cell5.ports["o2"])
mziMatrix.add_port(name="out2", port=mzi_cell6.ports["o2"])
mziMatrix.add_port(name="out1", port=mzi_cell6.ports["o1"])
mziMatrix.draw_ports()

# ========================================
#       electrical ports
# ========================================
# mzi 1
mziMatrix.add_port(name="e1", port=mzi_cell1.ports["ei1"])
mziMatrix.add_port(name="e2", port=mzi_cell1.ports["eo1"])
mziMatrix.add_port(name="e3", port=mzi_cell1.ports["eo2"])
# mzi 2
mziMatrix.add_port(name="e4", port=mzi_cell2.ports["ei1"])
mziMatrix.add_port(name="e5", port=mzi_cell2.ports["eo1"])
mziMatrix.add_port(name="e6", port=mzi_cell2.ports["eo2"])
# mzi 3
mziMatrix.add_port(name="e7", port=mzi_cell3.ports["ei1"])
mziMatrix.add_port(name="e8", port=mzi_cell3.ports["eo1"])
mziMatrix.add_port(name="e9", port=mzi_cell3.ports["eo2"])
# mzi 4
mziMatrix.add_port(name="e10", port=mzi_cell4.ports["ei1"])
mziMatrix.add_port(name="e11", port=mzi_cell4.ports["eo1"])
mziMatrix.add_port(name="e12", port=mzi_cell4.ports["eo2"])
# mzi 5
mziMatrix.add_port(name="e13", port=mzi_cell5.ports["ei1"])
mziMatrix.add_port(name="e14", port=mzi_cell5.ports["eo1"])
mziMatrix.add_port(name="e15", port=mzi_cell5.ports["eo2"])
# mzi 6
mziMatrix.add_port(name="e16", port=mzi_cell6.ports["ei1"])
mziMatrix.add_port(name="e17", port=mzi_cell6.ports["eo1"])
mziMatrix.add_port(name="e18", port=mzi_cell6.ports["eo2"])

mziMatrix.pprint_ports()

mziMatrix.draw_ports()

mziMatrix.plot()

import yaml

n = mziMatrix.get_netlist()

mziMatrix.plot_netlist()

# ============

mziMatrix.show()
# Out:
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ orientation ┃ layer       ┃ center             ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ in1  │ 0.5   │ 180.0       │ WG (1/0)    │ (-231.0, -121.875) │ optical    │
# │ in2  │ 0.5   │ 180.0       │ WG (1/0)    │ (-231.0, -40.625)  │ optical    │
# │ in3  │ 0.5   │ 180.0       │ WG (1/0)    │ (-50.0, 40.625)    │ optical    │
# │ in4  │ 0.5   │ 180.0       │ WG (1/0)    │ (131.0, 121.875)   │ optical    │
# │ out4 │ 0.5   │ 0.0         │ WG (1/0)    │ (312.0, 121.875)   │ optical    │
# │ out3 │ 0.5   │ 0.0         │ WG (1/0)    │ (493.0, 40.625)    │ optical    │
# │ out2 │ 0.5   │ 0.0         │ WG (1/0)    │ (674.0, -40.625)   │ optical    │
# │ out1 │ 0.5   │ 0.0         │ WG (1/0)    │ (674.0, -121.875)  │ optical    │
# │ e1   │ 11.0  │ 90.0        │ MTOP (49/0) │ (-155.9, -53.125)  │ electrical │
# │ e2   │ 10.0  │ 180.0       │ MTOP (49/0) │ (-75.0, -60.625)   │ electrical │
# │ e3   │ 10.0  │ 180.0       │ MTOP (49/0) │ (-75.0, -101.875)  │ electrical │
# │ e4   │ 11.0  │ 90.0        │ MTOP (49/0) │ (25.1, 28.125)     │ electrical │
# │ e5   │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, 20.625)    │ electrical │
# │ e6   │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, -20.625)   │ electrical │
# │ e7   │ 11.0  │ 90.0        │ MTOP (49/0) │ (206.1, 109.375)   │ electrical │
# │ e8   │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, 101.875)   │ electrical │
# │ e9   │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, 60.625)    │ electrical │
# │ e10  │ 11.0  │ 90.0        │ MTOP (49/0) │ (206.1, -53.125)   │ electrical │
# │ e11  │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, -60.625)   │ electrical │
# │ e12  │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, -101.875)  │ electrical │
# │ e13  │ 11.0  │ 90.0        │ MTOP (49/0) │ (387.1, 28.125)    │ electrical │
# │ e14  │ 10.0  │ 180.0       │ MTOP (49/0) │ (468.0, 20.625)    │ electrical │
# │ e15  │ 10.0  │ 180.0       │ MTOP (49/0) │ (468.0, -20.625)   │ electrical │
# │ e16  │ 11.0  │ 90.0        │ MTOP (49/0) │ (568.1, -53.125)   │ electrical │
# │ e17  │ 10.0  │ 180.0       │ MTOP (49/0) │ (649.0, -60.625)   │ electrical │
# │ e18  │ 10.0  │ 180.0       │ MTOP (49/0) │ (649.0, -101.875)  │ electrical │
# └──────┴───────┴─────────────┴─────────────┴────────────────────┴────────────┘
# 2025-06-16 11:53:37.817 | INFO     | kfactory.kcell:show:8802 - klive v0.3.3: Reloaded file '/Users/taufiqhidayat/Documents/EL4064/build/gds/4292590140.oas'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 Code(filename=PATH.klayout_yaml)
#
# NameError: name 'Code' is not defined

# %%
# ========================================
#       add fiber array I/O
# ========================================
mziMatrixIo = gf.routing.add_fiber_array(component=mziMatrix)

mziMatrixIo.plot()

mziMatrixIo.pprint_ports()

mziMatrixIo.plot_netlist()
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ name      ┃ width ┃ orientation ┃ layer       ┃ center             ┃ port_type   ┃
# ┡━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ in1       │ 10.0  │ 270.0       │ WG (1/0)    │ (-223.0, -225.115) │ vertical_te │
# │ in2       │ 10.0  │ 270.0       │ WG (1/0)    │ (-96.0, -225.115)  │ vertical_te │
# │ in3       │ 10.0  │ 270.0       │ WG (1/0)    │ (31.0, -225.115)   │ vertical_te │
# │ in4       │ 10.0  │ 270.0       │ WG (1/0)    │ (158.0, -225.115)  │ vertical_te │
# │ out4      │ 10.0  │ 270.0       │ WG (1/0)    │ (285.0, -225.115)  │ vertical_te │
# │ out3      │ 10.0  │ 270.0       │ WG (1/0)    │ (412.0, -225.115)  │ vertical_te │
# │ out2      │ 10.0  │ 270.0       │ WG (1/0)    │ (539.0, -225.115)  │ vertical_te │
# │ out1      │ 10.0  │ 270.0       │ WG (1/0)    │ (666.0, -225.115)  │ vertical_te │
# │ e1        │ 11.0  │ 90.0        │ MTOP (49/0) │ (-155.9, -53.125)  │ electrical  │
# │ e2        │ 10.0  │ 180.0       │ MTOP (49/0) │ (-75.0, -60.625)   │ electrical  │
# │ e3        │ 10.0  │ 180.0       │ MTOP (49/0) │ (-75.0, -101.875)  │ electrical  │
# │ e4        │ 11.0  │ 90.0        │ MTOP (49/0) │ (25.1, 28.125)     │ electrical  │
# │ e5        │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, 20.625)    │ electrical  │
# │ e6        │ 10.0  │ 180.0       │ MTOP (49/0) │ (106.0, -20.625)   │ electrical  │
# │ e7        │ 11.0  │ 90.0        │ MTOP (49/0) │ (206.1, 109.375)   │ electrical  │
# │ e8        │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, 101.875)   │ electrical  │
# │ e9        │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, 60.625)    │ electrical  │
# │ e10       │ 11.0  │ 90.0        │ MTOP (49/0) │ (206.1, -53.125)   │ electrical  │
# │ e11       │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, -60.625)   │ electrical  │
# │ e12       │ 10.0  │ 180.0       │ MTOP (49/0) │ (287.0, -101.875)  │ electrical  │
# │ e13       │ 11.0  │ 90.0        │ MTOP (49/0) │ (387.1, 28.125)    │ electrical  │
# │ e14       │ 10.0  │ 180.0       │ MTOP (49/0) │ (468.0, 20.625)    │ electrical  │
# │ e15       │ 10.0  │ 180.0       │ MTOP (49/0) │ (468.0, -20.625)   │ electrical  │
# │ e16       │ 11.0  │ 90.0        │ MTOP (49/0) │ (568.1, -53.125)   │ electrical  │
# │ e17       │ 10.0  │ 180.0       │ MTOP (49/0) │ (649.0, -60.625)   │ electrical  │
# │ e18       │ 10.0  │ 180.0       │ MTOP (49/0) │ (649.0, -101.875)  │ electrical  │
# │ loopback1 │ 10.0  │ 270.0       │ WG (1/0)    │ (-350.0, -225.115) │ vertical_te │
# │ loopback2 │ 10.0  │ 270.0       │ WG (1/0)    │ (793.0, -225.115)  │ vertical_te │
# └───────────┴───────┴─────────────┴─────────────┴────────────────────┴─────────────┘

# %%
from gdsfactory.generic_tech.layer_stack import get_layer_stack

layer_stack220 = get_layer_stack()

scene = mziMatrixIo.to_3d(layer_stack=layer_stack220)

scene.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 5
#       1 from gdsfactory.generic_tech.layer_stack import get_layer_stack
#       3 layer_stack220 = get_layer_stack()
# ----> 5 scene = mziMatrixIo.to_3d(layer_stack=layer_stack220)
#       7 scene.show()
#
# File ~/anaconda3/lib/python3.12/site-packages/gdsfactory/component.py:962, in ComponentBase.to_3d(self, layer_views, layer_stack, exclude_layers)
#     949 """Return Component 3D trimesh Scene.
#     950
#     951 Args:
#    (...)
#     958
#     959 """
#     960 from gdsfactory.export.to_3d import to_3d
# --> 962 return to_3d(
#     963     self,
#     964     layer_views=layer_views,
#     965     layer_stack=layer_stack,
#     966     exclude_layers=exclude_layers,
#     967 )
#
# File ~/anaconda3/lib/python3.12/site-packages/gdsfactory/export/to_3d.py:77, in to_3d(component, layer_views, layer_stack, exclude_layers)
#      74     continue
#      76 zmin = level.zmin
# ---> 77 layer_view = layer_views.get_from_tuple(layer_tuple)
#      78 color_rgb = [c / 255 for c in layer_view.fill_color.as_rgb_tuple(alpha=False)]
#      79 if zmin is not None and layer_view.visible:
#
# File ~/anaconda3/lib/python3.12/site-packages/gdsfactory/technology/layer_views.py:931, in LayerViews.get_from_tuple(self, layer_tuple)
#     929 tuple_to_name = {v.layer: k for k, v in self.get_layer_views().items()}
#     930 if layer_tuple not in tuple_to_name:
# --> 931     raise ValueError(
#     932         f"LayerView {layer_tuple} not in {list(tuple_to_name.keys())}"
#     933     )
#     935 name = tuple_to_name[layer_tuple]
#     936 return self.get_layer_views()[name]
#
# ValueError: LayerView (44, 0) not in [(1, 0), (31, 0), (2, 0), (11, 0), (12, 0), (13, 0), (47, 0), (4, 0), (6, 0), (10, 0), (203, 0), (204, 0), (206, 0), (99, 0), (733, 0), (68, 0), (1, 10), (81, 0), (66, 0), (69, 0), (1, 11), (300, 0), (301, 0), (319, 0), (320, 0), (321, 0), (330, 0), (327, 0), (331, 0), (313, 0), (311, 0), (302, 0), (315, 0), (303, 0), (304, 0), (305, 0), (306, 0), (307, 0), (317, 0), (309, 0), (399, 0), (310, 0), (205, 0), (207, 0), (1, 12), (100, 0), (101, 0), (110, 0)]

# %%
import gplugins as sim
import gplugins.tidy3d as gt

import ubcpdk.components as pdk
from ubcpdk.config import PATH
# Out:
# /Users/taufiqhidayat/anaconda3/lib/python3.12/site-packages/sax/backends/__init__.py:58: UserWarning: klujax not found. Please install klujax for better performance during circuit evaluation!
#   warnings.warn(

# %%
sp = gt.write_sparameters(mziMatrix, filepath=PATH.sparameters / "mziMatrix.npz")
# Out:
# 11:16:05 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
# 11:16:06 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
# 11:16:07 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# 11:16:08 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# 11:16:09 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# 11:16:10 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# 11:16:11 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# 11:16:12 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
# Output()
# 11:16:19 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
# 11:16:20 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Started working on Batch containing 8 tasks.
# 11:16:27 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Suppressed 1 WARNING message.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: Suppressed 1 WARNING message.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
# 11:16:28 WIB WARNING: 'simulation.structures[0]' is outside of the simulation
#              domain.
#              WARNING: Structure at structures[3] was detected as being less than
#              half of a central wavelength from a PML on side z-max. To avoid
#              inaccurate results or divergence, please increase gap between any
#              structures and PML or fully extend structure through the pml.
#              ERROR: Simulation has 6.35e+10 computational cells, a maximum of
#              2.00e+10 are allowed.
# ---------------------------------------------------------------------------
# SetupError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sp = gt.write_sparameters(mziMatrix, filepath=PATH.sparameters / "mziMatrix.npz")
#
# File ~/anaconda3/lib/python3.12/site-packages/gplugins/tidy3d/component.py:601, in write_sparameters(component, layer_stack, material_mapping, extend_ports, port_offset, pad_xy_inner, pad_xy_outer, pad_z_inner, pad_z_outer, dilation, wavelength, bandwidth, num_freqs, min_steps_per_wvl, center_z, sim_size_z, port_size_mult, run_only, element_mappings, extra_monitors, mode_spec, boundary_spec, symmetry, run_time, shutoff, folder_name, dirpath, verbose, plot_simulation_layer_name, plot_simulation_port_index, plot_simulation_z, plot_simulation_x, plot_mode_index, plot_mode_port_name, plot_epsilon, filepath, overwrite, **kwargs)
#     599 else:
#     600     time.sleep(0.2)
# --> 601     s = modeler.run()
#     602     for port_in in s.port_in.values:
#     603         for port_out in s.port_out.values:
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/plugins/smatrix/component_modelers/base.py:216, in AbstractComponentModeler.run(self, path_dir)
#     214 """Solves for the scattering matrix of the system."""
#     215 path_dir = self.get_path_dir(path_dir)
# --> 216 batch_data = self._run_sims(path_dir=path_dir)
#     217 return self._construct_smatrix(batch_data=batch_data)
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/plugins/smatrix/component_modelers/base.py:198, in AbstractComponentModeler._run_sims(self, path_dir)
#     195 """Run :class:`Simulations` for each port and return the batch after saving."""
#     196 batch = self.batch
# --> 198 batch_data = batch.run(path_dir=path_dir)
#     199 batch.to_file(self._batch_path)
#     200 return batch_data
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:557, in Batch.run(self, path_dir)
#     555 self.upload()
#     556 self.start()
# --> 557 self.monitor()
#     558 self.download(path_dir=path_dir)
#     559 return self.load(path_dir=path_dir)
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:713, in Batch.monitor(self)
#     710 if self.verbose:
#     711     console = get_logging_console()
# --> 713     self.estimate_cost()
#     714     console.log(
#     715         "Use 'Batch.real_cost()' to "
#     716         "get the billed FlexCredit cost after the Batch has completed."
#     717     )
#     719     with Progress(console=console) as progress:
#     720         # create progressbars
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:929, in Batch.estimate_cost(self, verbose)
#     911 def estimate_cost(self, verbose: bool = True) -> float:
#     912     """Compute the maximum FlexCredit charge for a given :class:`.Batch`.
#     913
#     914     Parameters
#    (...)
#     927         Estimated total cost of the tasks in FlexCredits.
#     928     """
# --> 929     job_costs = [job.estimate_cost(verbose=False) for _, job in self.jobs.items()]
#     930     if any(cost is None for cost in job_costs):
#     931         batch_cost = None
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:340, in Job.estimate_cost(self, verbose)
#     322 def estimate_cost(self, verbose: bool = True) -> float:
#     323     """Compute the maximum FlexCredit charge for a given :class:`.Job`.
#     324
#     325     Parameters
#    (...)
#     338     the full ``run_time``. If early shut-off is triggered, the cost is adjusted proportionately.
#     339     """
# --> 340     return web.estimate_cost(self.task_id, verbose=verbose, solver_version=self.solver_version)
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/components/base.py:56, in cache.<locals>.cached_property_getter(self)
#      53 if stored_value is not None:
#      54     return stored_value
# ---> 56 computed_value = prop(self)
#      57 self._cached_properties[prop_name] = computed_value
#      58 return computed_value
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:215, in Job.task_id(self)
#     213 if self.task_id_cached:
#     214     return self.task_id_cached
# --> 215 return self._upload()
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/container.py:222, in Job._upload(self)
#     220 self_dict = self.dict()
#     221 upload_kwargs = {key: self_dict.get(key) for key in self._upload_fields}
# --> 222 task_id = web.upload(**upload_kwargs)
#     223 return task_id
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/connect_util.py:34, in wait_for_connection.<locals>.decorator.<locals>.web_fn_wrapped(*args, **kwargs)
#      32 while (time.time() - time_start) < wait_time_sec:
#      33     try:
# ---> 34         return web_fn(*args, **kwargs)
#      35     except (ConnErr, ConnectionError, NewConnectionError, ReadTimeout, JSONDecodeError):
#      36         if not warned_previously:
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/webapi.py:214, in upload(simulation, task_name, folder_name, callback_url, verbose, progress_callback, simulation_type, parent_tasks, source_required)
#     170 """
#     171 Upload simulation to server, but do not start running :class:`.Simulation`.
#     172
#    (...)
#     211
#     212 """
#     213 stub = Tidy3dStub(simulation=simulation)
# --> 214 stub.validate_pre_upload(source_required=source_required)
#     215 log.debug("Creating task.")
#     217 task_type = stub.get_type()
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/web/api/tidy3d_stub.py:134, in Tidy3dStub.validate_pre_upload(self, source_required)
#     132 """Perform some pre-checks on instances of component"""
#     133 if isinstance(self.simulation, Simulation):
# --> 134     self.simulation.validate_pre_upload(source_required)
#     135 elif isinstance(self.simulation, EMESimulation):
#     136     self.simulation.validate_pre_upload()
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/components/simulation.py:3409, in Simulation.validate_pre_upload(self, source_required)
#    3401 """Validate the fully initialized simulation is ok for upload to our servers.
#    3402
#    3403 Parameters
#    (...)
#    3406     If ``True``, validation will fail in case no sources are found in the simulation.
#    3407 """
#    3408 log.begin_capture()
# -> 3409 self._validate_size()
#    3410 self._validate_monitor_size()
#    3411 self._validate_modes_size()
#
# File ~/anaconda3/lib/python3.12/site-packages/tidy3d/components/simulation.py:3427, in Simulation._validate_size(self)
#    3425 num_comp_cells = self.num_cells / 2 ** (np.sum(np.abs(self.symmetry)))
#    3426 if num_comp_cells > MAX_GRID_CELLS:
# -> 3427     raise SetupError(
#    3428         f"Simulation has {num_comp_cells:.2e} computational cells, "
#    3429         f"a maximum of {MAX_GRID_CELLS:.2e} are allowed."
#    3430     )
#    3432 num_time_steps = self.num_time_steps
#    3433 if num_time_steps > MAX_TIME_STEPS:
#
# SetupError: Simulation has 6.35e+10 computational cells, a maximum of 2.00e+10 are allowed.

# %%
c = gf.components.grating_coupler_elliptical_lumerical()
fiber_angles = [3, 5, 7]
jobs = [
    dict(
        component=c,
        is_3d=False,
        fiber_angle_deg=fiber_angle_deg,
        filepath=PATH.sparameters_repo / f"gc_angle{fiber_angle_deg}",
    )
    for fiber_angle_deg in fiber_angles
]
sps = gt.write_sparameters_grating_coupler_batch(jobs)

# %%
for sp, fiber_angle_deg in zip(sps, fiber_angles):
    sp = sp.result()
    plt.plot(
        sp["wavelengths"],
        20 * np.log10(np.abs(sp["o2@0,o1@0"])),
        label=str(fiber_angle_deg),
    )

plt.xlabel("wavelength (um")
plt.ylabel("Transmission (dB)")
plt.title("transmission vs fiber angle (degrees)")
plt.legend()
