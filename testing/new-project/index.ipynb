# %% [markdown]
# this part is a markdown inside .ipynb file.
# this part won't be compiled

# %%
# this part is a code inside .ipynb file.
import gdsfactory as gf
c = gf.components.straight(length=10, npoints=2, cross_section='strip').copy()
c.draw_ports()
c.plot()

# %% [markdown]
# run this index.ipynb and see what happens.
